# %%
import numpy as np
from scipy.sparse.linalg import svds
from collections import defaultdict, Counter
from scipy.sparse import coo_matrix

# %%
file_path = 'ans.txt'
window_size=5
vocab_size=20000

# %%
# 构建共现矩阵
def build_cooccurrence_matrix(file_path, window_size=5, vocab_size = 10000):
    # 读取文本文件中的所有单词，并统计每个单词出现的次数
    with open(file_path, 'r', encoding='utf-8') as file:
        words = file.read().split()

    count = []
    count.extend(Counter(words).most_common(vocab_size))

    # 将出现次数最多的前vocab_size个单词作为词汇表
    vocab = [v[0] for v in count]
    vocab = set(vocab)

    # 创建一个空的defaultdict，用于记录每对单词的共现频率
    cooccurrence_matrix = defaultdict(int)

    # 计算每个词语的频率和共现频率
    for i, word in enumerate(words):
        if word in vocab:
            for j in range(i - window_size, i + window_size + 1):
                if j >= 0 and j < len(words) and word != words[j] and words[j] in vocab:
                    cooccurrence_matrix[word, words[j]] += 1

    # 创建一个从词语到索引的映射
    word_to_index = {word: index for index, word in enumerate(vocab)}

    # 初始化一个COO格式的稀疏矩阵，其行数和列数等于词汇表的大小
    cmatrix = coo_matrix((vocab_size, vocab_size))

    # 填充稀疏矩阵的值、行索引和列索引
    rows = []
    cols = []
    data = []
    for (i, j), value in cooccurrence_matrix.items():
        row_index = word_to_index[i]
        col_index = word_to_index[j]
        rows.append(float(row_index))
        cols.append(float(col_index))
        data.append(float(value))

    # 将行索引、列索引和数据列表赋值给COO格式的稀疏矩阵
    cmatrix.data = np.array(data)
    cmatrix.row = np.array(rows)
    cmatrix.col = np.array(cols)

    # 转换为CSR格式，这样可以进行更多的稀疏矩阵操作
    csr_matrix = cmatrix.tocsr()

    return csr_matrix, vocab, word_to_index

# %%
csr_matrix, vocab, word_to_index = build_cooccurrence_matrix(file_path, window_size=window_size, vocab_size=vocab_size)

# %%
# 定义一个函数，用于将稀疏矩阵应用SVD分解并降维
def svd_embedding(csr_matrix, n_components=5):
    # 使用SVD进行降维，返回三个矩阵：U、sigma和Vt
    U, sigma, Vt = svds(csr_matrix, k=n_components)
    
    # 重新组合U和Vt来形成词向量
    embeddings = np.dot(U, np.diag(sigma))
    
    # 计算每个词向量的范数
    scalar_array = np.linalg.norm(embeddings, axis=1)
    
    # 对词向量进行归一化处理
    embeddings = (embeddings.T / scalar_array).T
    
    return embeddings  # 返回降维后的词向量

# %%
embeddings, sigma = svd_embedding(csr_matrix, n_components=10)

# %%
# 读取文件并解析每一行
with open('pku_sim_test.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 初始化一个列表来存储每对子词的余弦相似度
similarity_list = []

# 遍历每一行
for line in lines:
    # 分割每行中的两个子词
    words = line.strip().split()
    
    # 检查两个子词是否都在word_embeddings中
    if len(words) == 2 and words[0] in vocab and words[1] in vocab:
        # 获取两个子词的词向量
        vec1 = embeddings[word_to_index[words[0]]]
        vec2 = embeddings[word_to_index[words[1]]]
        
        # 归一化向量
        vec1_normalized = vec1 / np.linalg.norm(vec1)
        vec2_normalized = vec2 / np.linalg.norm(vec2)
        
        # 计算余弦相似度
        dot_product = np.dot(vec1, vec2)

        sim_svd = dot_product 
        
        # 将余弦相似度添加到列表中
        similarity_list.append(sim_svd)
    else:
        # 如果任一词向量不存在，设置相似度为0
        similarity_list.append(0.0)

# 打印或存储余弦相似度结果
for words, sim in zip(lines, similarity_list):
    print(f'Words: {words.strip()}, Cosine Similarity: {sim}')
# Out:
# Words: 没戏	没辙, Cosine Similarity: 0.0
# Words: 只管	尽管, Cosine Similarity: 0.9367185644738738
# Words: GDP	生产力, Cosine Similarity: 0.9699678618230898
# Words: 包袱	段子, Cosine Similarity: 0.0
# Words: 由此	通过, Cosine Similarity: 0.9876394811448563
# Words: 日期	时间, Cosine Similarity: 0.9777036838558274
# Words: 爱面子	好高骛远, Cosine Similarity: 0.0
# Words: 严厉	严谨, Cosine Similarity: 0.9619034018858785
# Words: 一方面	一边, Cosine Similarity: 0.9163011574531352
# Words: 托福	GRE, Cosine Similarity: 0.0
# Words: 亏	幸亏, Cosine Similarity: 0.0
# Words: 蹩脚	差强人意, Cosine Similarity: 0.0
# Words: 容易	顺利, Cosine Similarity: 0.9244490963214902
# Words: 悲喜	大悲大喜, Cosine Similarity: 0.0
# Words: 老气	土气, Cosine Similarity: 0.0
# Words: 狭隘	狭窄, Cosine Similarity: 0.9698297337290985
# Words: 抄袭	克隆, Cosine Similarity: 0.0
# Words: 害臊	腼腆, Cosine Similarity: 0.0
# Words: 幻境	红楼梦, Cosine Similarity: 0.0
# Words: 依稀	清晰, Cosine Similarity: 0.9540591418157502
# Words: 权限	权力, Cosine Similarity: 0.9631328655496383
# Words: 伟大	壮烈, Cosine Similarity: 0.9753527383550187
# Words: 娇艳	幽美, Cosine Similarity: 0.0
# Words: 理解	理会, Cosine Similarity: 0.0
# Words: 酣睡	打鼾, Cosine Similarity: 0.0
# Words: 自然	环境, Cosine Similarity: 0.9778741533300451
# Words: 振兴	建设, Cosine Similarity: 0.9832335051758888
# Words: 节日	假日, Cosine Similarity: 0.9705676742030473
# Words: 的哥	司机, Cosine Similarity: 0.0
# Words: 几乎	差点儿, Cosine Similarity: 0.0
# Words: 江湖	红尘, Cosine Similarity: 0.0
# Words: 路子	后门, Cosine Similarity: 0.0
# Words: 牛脾气	我行我素, Cosine Similarity: 0.0
# Words: 物品	物质, Cosine Similarity: 0.9792571013996327
# Words: 塞车	拥挤, Cosine Similarity: 0.8919167700325228
# Words: 面	首, Cosine Similarity: 0.9767045186675125
# Words: 冷僻	晦涩, Cosine Similarity: 0.0
# Words: 免费	便宜, Cosine Similarity: 0.9189331474508599
# Words: 发票	账单, Cosine Similarity: 0.0
# Words: 回收站	垃圾篓, Cosine Similarity: 0.0
# Words: 典型	代表, Cosine Similarity: 0.9620777589892267
# Words: 必须	必需, Cosine Similarity: 0.9581660448478124
# Words: 出神	发楞, Cosine Similarity: 0.0
# Words: 琢磨	镂刻, Cosine Similarity: 0.0
# Words: 身姿	身手, Cosine Similarity: 0.0
# Words: 质量	重量, Cosine Similarity: 0.9883575254010362
# Words: 事变	后院起火, Cosine Similarity: 0.0
# Words: 大小	多少, Cosine Similarity: 0.9100963015775594
# Words: 信物	证件, Cosine Similarity: 0.0
# Words: 牺牲	粉身碎骨, Cosine Similarity: 0.0
# Words: 豆蔻年华	黄金时代, Cosine Similarity: 0.0
# Words: 血液	红细胞, Cosine Similarity: 0.0
# Words: 硅谷	中关村, Cosine Similarity: 0.9589247811795185
# Words: 天赋	技能, Cosine Similarity: 0.9082570785714048
# Words: 酷	爽, Cosine Similarity: 0.0
# Words: 旅客	驴友, Cosine Similarity: 0.0
# Words: 隆重	重要, Cosine Similarity: 0.7427183636658942
# Words: 候选人	备胎, Cosine Similarity: 0.0
# Words: 平凡	平庸, Cosine Similarity: 0.9557516802087258
# Words: 了不得	好, Cosine Similarity: 0.0
# Words: 鸣谢	酬答, Cosine Similarity: 0.0
# Words: 线路	行程, Cosine Similarity: 0.9702778438502699
# Words: 多角度	多元化, Cosine Similarity: 0.0
# Words: 要面子	虚荣心, Cosine Similarity: 0.0
# Words: 许可证	执照, Cosine Similarity: 0.0
# Words: 是非	方圆, Cosine Similarity: 0.9353482777047533
# Words: 崛起	凸起, Cosine Similarity: 0.0
# Words: 工作日	开放日, Cosine Similarity: 0.0
# Words: 大	高, Cosine Similarity: 0.9910869698492424
# Words: 吸引力	地磁力, Cosine Similarity: 0.0
# Words: 右翼	左派, Cosine Similarity: 0.0
# Words: 和谐	平安, Cosine Similarity: 0.9446916317445846
# Words: 商标	符号, Cosine Similarity: 0.8866037364599103
# Words: 违纪	贪污, Cosine Similarity: 0.9470935562182718
# Words: 环境	生态, Cosine Similarity: 0.99409113544884
# Words: 实践	进行, Cosine Similarity: 0.969289747554466
# Words: 买卖	营销, Cosine Similarity: 0.9617130181752784
# Words: 合理	合理性, Cosine Similarity: 0.9795297794770333
# Words: 辛勤	夜以继日, Cosine Similarity: 0.9000092486748248
# Words: 手续	过程, Cosine Similarity: 0.8560249321793223
# Words: 渣	废品, Cosine Similarity: 0.9648084177154681
# Words: 高峰	山巅, Cosine Similarity: 0.0
# Words: 收费	缴纳, Cosine Similarity: 0.9794431174323572
# Words: 享受	大快朵颐, Cosine Similarity: 0.0
# Words: 怯懦	胆小鬼, Cosine Similarity: 0.0
# Words: 杂事	闲事, Cosine Similarity: 0.0
# Words: 言语	语言, Cosine Similarity: 0.0
# Words: 借口	理由, Cosine Similarity: 0.9659088760816711
# Words: 与	以及, Cosine Similarity: 0.9763462432800352
# Words: 怯弱	狗熊, Cosine Similarity: 0.0
# Words: 惠顾	照顾, Cosine Similarity: 0.0
# Words: 迷人	气质, Cosine Similarity: 0.9539774660104283
# Words: 果粉	米粉, Cosine Similarity: 0.0
# Words: 榜样	样子, Cosine Similarity: 0.9102655902059767
# Words: 愚钝	大智若愚, Cosine Similarity: 0.0
# Words: 打假	扫黄, Cosine Similarity: 0.7318556559254974
# Words: 均衡	全面, Cosine Similarity: 0.9686810994015916
# Words: 制约	收敛, Cosine Similarity: 0.0
# Words: 经营者	纳税人, Cosine Similarity: 0.9918791100572081
# Words: 瘦弱	苗条, Cosine Similarity: 0.0
# Words: 前途	道路, Cosine Similarity: 0.9671338492120614
# Words: 遛弯	走路, Cosine Similarity: 0.0
# Words: 爱心	慈善, Cosine Similarity: 0.9347028328173436
# Words: 光盘	硬盘, Cosine Similarity: 0.0
# Words: 一体化	集成化, Cosine Similarity: 0.0
# Words: 销魂	陶醉, Cosine Similarity: 0.0
# Words: 光荣	流芳百世, Cosine Similarity: 0.0
# Words: 观后感	影评, Cosine Similarity: 0.0
# Words: 恼怒	愤慨, Cosine Similarity: 0.0
# Words: 帮助	赞助, Cosine Similarity: 0.9861341921444697
# Words: 拥戴	崇拜, Cosine Similarity: 0.9395232918720282
# Words: 扯淡	闲聊, Cosine Similarity: 0.0
# Words: 旅程	旅行, Cosine Similarity: 0.9630811010122182
# Words: 男孩	小伙子, Cosine Similarity: 0.9667048542839607
# Words: 见解	意见, Cosine Similarity: 0.96626668619802
# Words: 穷苦	贫穷, Cosine Similarity: 0.0
# Words: 生命	性命, Cosine Similarity: 0.9250669284276226
# Words: 滚蛋	滚开, Cosine Similarity: 0.0
# Words: 维他命	维生素, Cosine Similarity: 0.0
# Words: 多元化	年轻化, Cosine Similarity: 0.0
# Words: 宝贵	金子, Cosine Similarity: 0.9573668029622011
# Words: 结构	系统, Cosine Similarity: 0.9791390864117606
# Words: 玩偶	工具, Cosine Similarity: 0.0
# Words: 丧失	失独, Cosine Similarity: 0.0
# Words: 肚量	肚子, Cosine Similarity: 0.0
# Words: 娇气	公主, Cosine Similarity: 0.0
# Words: 寒暑假	黄金周, Cosine Similarity: 0.0
# Words: 笑料	活宝, Cosine Similarity: 0.0
# Words: 百货	商场, Cosine Similarity: 0.0
# Words: 信息化	智能化, Cosine Similarity: 0.0
# Words: 茶道	茶叶, Cosine Similarity: 0.0
# Words: 罪孽	犯人, Cosine Similarity: 0.0
# Words: 感冒药	退烧药, Cosine Similarity: 0.0
# Words: 难点	问题, Cosine Similarity: 0.9736625749250487
# Words: 同事	朋友, Cosine Similarity: 0.9771035836608621
# Words: 名字	姓氏, Cosine Similarity: 0.0
# Words: 网站	网页, Cosine Similarity: 0.8059745072914676
# Words: 名誉	名气, Cosine Similarity: 0.7881089909191934
# Words: 七情六欲	欲望, Cosine Similarity: 0.0
# Words: 审理	问讯, Cosine Similarity: 0.0
# Words: 工具	器具, Cosine Similarity: 0.0
# Words: 意思	意义, Cosine Similarity: 0.9398211710504598
# Words: 优惠	降价, Cosine Similarity: 0.9615738342073522
# Words: 伴随	陪伴, Cosine Similarity: 0.8702881660241826
# Words: 尘垢	污秽, Cosine Similarity: 0.0
# Words: 猫腻	阴谋诡计, Cosine Similarity: 0.0
# Words: 吃醋	争风吃醋, Cosine Similarity: 0.0
# Words: 软着陆	经济, Cosine Similarity: 0.0
# Words: 生产力	创新, Cosine Similarity: 0.9856553766276
# Words: 上市	盈利, Cosine Similarity: 0.9778336694594978
# Words: 泼妇	女强人, Cosine Similarity: 0.0
# Words: 载体	书本, Cosine Similarity: 0.9284588128648388
# Words: 地址	小区, Cosine Similarity: 0.9136516940039118
# Words: 价钱	票房, Cosine Similarity: 0.865185483950595
# Words: 表彰	进步, Cosine Similarity: 0.9661931738834213
# Words: 理论	结论, Cosine Similarity: 0.9417225049670991
# Words: 烦闷	失眠, Cosine Similarity: 0.0
# Words: 亲人	敌人, Cosine Similarity: 0.9870202651769537
# Words: 跳槽	移动, Cosine Similarity: 0.9261388659403731
# Words: 饮酒	喝茶, Cosine Similarity: 0.9172600255559578
# Words: 财运	桃花运, Cosine Similarity: 0.0
# Words: 女权	女性, Cosine Similarity: 0.0
# Words: 一般	差, Cosine Similarity: 0.9876469090075884
# Words: 赌局	扑克牌, Cosine Similarity: 0.0
# Words: 宋	明, Cosine Similarity: 0.9716073890091586
# Words: 雾霾	阴天, Cosine Similarity: 0.0
# Words: 程序	指令, Cosine Similarity: 0.8994743633367361
# Words: 关键字	关键, Cosine Similarity: 0.0
# Words: 松驰	疲软, Cosine Similarity: 0.0
# Words: 平等	平均, Cosine Similarity: 0.9832810718236644
# Words: 经营	张罗, Cosine Similarity: 0.0
# Words: 客套	礼貌, Cosine Similarity: 0.0
# Words: 利用	使用, Cosine Similarity: 0.9958020222473845
# Words: 审查	自纠自查, Cosine Similarity: 0.0
# Words: 炖	焖, Cosine Similarity: 0.0
# Words: 喜欢	崇敬, Cosine Similarity: 0.959380825130566
# Words: 暗号	密码, Cosine Similarity: 0.0
# Words: 规律	原理, Cosine Similarity: 0.9846067421559178
# Words: 轻率	鲁莽, Cosine Similarity: 0.0
# Words: 手法	方法, Cosine Similarity: 0.9893896876065884
# Words: 准则	规则, Cosine Similarity: 0.9885160049311252
# Words: 迂腐	墨守成规, Cosine Similarity: 0.0
# Words: 闯祸	惹是生非, Cosine Similarity: 0.0
# Words: 清晰	一清二楚, Cosine Similarity: 0.0
# Words: 姐妹	闺蜜, Cosine Similarity: 0.0
# Words: 扎实	脚踏实地, Cosine Similarity: 0.9537646847962469
# Words: 事物	东西, Cosine Similarity: 0.9640250389633207
# Words: 睡	寐, Cosine Similarity: 0.0
# Words: 忌妒	妒嫉, Cosine Similarity: 0.0
# Words: 俱乐部	富人, Cosine Similarity: 0.0
# Words: 味道	鼻子, Cosine Similarity: 0.9039901112124105
# Words: 绩点	老师, Cosine Similarity: 0.0
# Words: 关心	放任, Cosine Similarity: 0.8501081731360716
# Words: 空间	世界, Cosine Similarity: 0.9853647459155388
# Words: 僻静	冷静, Cosine Similarity: 0.0
# Words: 字符	程序, Cosine Similarity: 0.0
# Words: 裁判	足球, Cosine Similarity: 0.990014062351073
# Words: 股票	银行, Cosine Similarity: 0.9943548950441875
# Words: 红颜	面容, Cosine Similarity: 0.0
# Words: 著名	著作, Cosine Similarity: 0.9858879099815054
# Words: 可能性	可靠性, Cosine Similarity: 0.8668569456159805
# Words: 占有	争取, Cosine Similarity: 0.9698486488980952
# Words: 合肥	巴黎, Cosine Similarity: 0.9207923694378861
# Words: 热线	焦点, Cosine Similarity: 0.874110250330541
# Words: 影响力	破坏力, Cosine Similarity: 0.0
# Words: 温度	湿度, Cosine Similarity: 0.9721863519454512
# Words: 痛苦	忍辱负重, Cosine Similarity: 0.0
# Words: 偶遇	艳遇, Cosine Similarity: 0.0
# Words: 公众	媒体, Cosine Similarity: 0.960085109897678
# Words: 姑娘	青春, Cosine Similarity: 0.9845899431740202
# Words: 多媒体	设备, Cosine Similarity: 0.9801123555169577
# Words: 韩	日, Cosine Similarity: 0.9959063122746894
# Words: 钱	利, Cosine Similarity: 0.8664592493000172
# Words: 细心	三心二意, Cosine Similarity: 0.0
# Words: 博物馆	剧院, Cosine Similarity: 0.9394605517385426
# Words: 诵读	歌唱, Cosine Similarity: 0.0
# Words: 阳光	雨露, Cosine Similarity: 0.0
# Words: 竞争	考试, Cosine Similarity: 0.9794571249581832
# Words: 消灭	灭菌, Cosine Similarity: 0.0
# Words: 饭局	交际, Cosine Similarity: 0.0
# Words: 媚俗	高雅, Cosine Similarity: 0.5986199983333159
# Words: 密码	账号, Cosine Similarity: 0.0
# Words: 夫人	孩子, Cosine Similarity: 0.8545565725451311
# Words: 简化	优化, Cosine Similarity: 0.9199092169273442
# Words: 侵害	性侵, Cosine Similarity: 0.0
# Words: 故事	剧情, Cosine Similarity: 0.0
# Words: 调整	整合, Cosine Similarity: 0.9850966230197425
# Words: 亲密	缠绵, Cosine Similarity: 0.0
# Words: 创新	发明, Cosine Similarity: 0.984496795916329
# Words: 带头	敢为人先, Cosine Similarity: 0.0
# Words: 公约	规章, Cosine Similarity: 0.9450649888464493
# Words: 高大上	超凡脱俗, Cosine Similarity: 0.0
# Words: 解闷	排遣, Cosine Similarity: 0.0
# Words: 放肆	大胆, Cosine Similarity: 0.0
# Words: 合同	协议, Cosine Similarity: 0.9841762159362075
# Words: 私语	嘀咕, Cosine Similarity: 0.0
# Words: 大概	差不多, Cosine Similarity: 0.9514767467274385
# Words: 比如	譬如, Cosine Similarity: 0.9800341431115092
# Words: 友善	清新, Cosine Similarity: 0.0
# Words: 胆小鬼	兔子, Cosine Similarity: 0.0
# Words: 繁荣	泡沫, Cosine Similarity: 0.996949377091102
# Words: 智力	想象, Cosine Similarity: 0.9592823266683577
# Words: 茶馆	企业, Cosine Similarity: 0.9402671673632781
# Words: 消极	四大皆空, Cosine Similarity: 0.0
# Words: 爱怜	同病相怜, Cosine Similarity: 0.0
# Words: 激励	缅怀, Cosine Similarity: 0.9432758568430677
# Words: 灌输	讲解, Cosine Similarity: 0.9747688378088208
# Words: 车辆	行人, Cosine Similarity: 0.9597046246137718
# Words: 偏见	认知, Cosine Similarity: 0.9748355321308748
# Words: 北京市	成都市, Cosine Similarity: 0.9467430957580122
# Words: 水果	西红柿, Cosine Similarity: 0.8143195811239156
# Words: 艺术家	地理学家, Cosine Similarity: 0.0
# Words: 干涉	管理, Cosine Similarity: 0.9752621847243477
# Words: 管理	托管, Cosine Similarity: 0.9531332358071266
# Words: 书籍	图书馆, Cosine Similarity: 0.9850174534712006
# Words: 框架	组织, Cosine Similarity: 0.9713554943447594
# Words: 炮兵	海军, Cosine Similarity: 0.0
# Words: 学习	上课, Cosine Similarity: 0.8476185045955893
# Words: 图书馆	文化宫, Cosine Similarity: 0.0
# Words: 欲望	情欲, Cosine Similarity: 0.0
# Words: 独立	啃老, Cosine Similarity: 0.0
# Words: 同学	同事, Cosine Similarity: 0.9625117683038773
# Words: 语文	数学, Cosine Similarity: 0.945838795519104
# Words: 低贱	崇高, Cosine Similarity: 0.0
# Words: 海域	渤海湾, Cosine Similarity: 0.0
# Words: 奖赏	惩罚, Cosine Similarity: 0.0
# Words: 名称	外号, Cosine Similarity: 0.0
# Words: 霸气	气场, Cosine Similarity: 0.0
# Words: 数据库	信息, Cosine Similarity: 0.9100263788898104
# Words: 波涛	海水, Cosine Similarity: 0.9850346392591629
# Words: 唱	颂, Cosine Similarity: 0.9226492626571725
# Words: 鬼话	谎言, Cosine Similarity: 0.0
# Words: 顺应	附和, Cosine Similarity: 0.0
# Words: 较真儿	死板, Cosine Similarity: 0.0
# Words: 乐观	阳光, Cosine Similarity: 0.9777298656417188
# Words: 羞辱	辱, Cosine Similarity: 0.0
# Words: 赋予	给予, Cosine Similarity: 0.963226991526696
# Words: 伪善	虚伪, Cosine Similarity: 0.0
# Words: 在行	熟练, Cosine Similarity: 0.0
# Words: 怪异	奇怪, Cosine Similarity: 0.0
# Words: 谦卑	谦逊, Cosine Similarity: 0.0
# Words: 反应	反响, Cosine Similarity: 0.8309962260088116
# Words: 过时	落伍, Cosine Similarity: 0.0
# Words: 金钱	钱财, Cosine Similarity: 0.8909552877517674
# Words: 种	栽, Cosine Similarity: 0.9911743443349684
# Words: 对话框	窗口, Cosine Similarity: 0.0
# Words: 弥补	补偿, Cosine Similarity: 0.9787000683707883
# Words: 财力	精力, Cosine Similarity: 0.9825073665701555
# Words: 功夫	素养, Cosine Similarity: 0.8948234782556679
# Words: 竞争力	鉴赏力, Cosine Similarity: 0.0
# Words: 比赛	团队, Cosine Similarity: 0.8762756137823359
# Words: 企业家	作曲家, Cosine Similarity: 0.0
# Words: 素菜	牛肉, Cosine Similarity: 0.0
# Words: 报警	报告, Cosine Similarity: 0.9066194996476559
# Words: 残疾	死亡, Cosine Similarity: 0.965151999877691
# Words: 指导	斥责, Cosine Similarity: 0.0
# Words: 利润	成本, Cosine Similarity: 0.985860427054062
# Words: 思想	智力, Cosine Similarity: 0.9851287994229954
# Words: 配合	违抗, Cosine Similarity: 0.0
# Words: 电话	邮件, Cosine Similarity: 0.0
# Words: 公司	代销店, Cosine Similarity: 0.0
# Words: 苹果	香蕉, Cosine Similarity: 0.0
# Words: 盈利	亏损, Cosine Similarity: 0.9817651416322764
# Words: 公益	善心, Cosine Similarity: 0.0
# Words: 总理	主席, Cosine Similarity: 0.9990243776887483
# Words: 医生	护士, Cosine Similarity: 0.9635908082738621
# Words: 疼爱	溺爱, Cosine Similarity: 0.0
# Words: 新闻界	舆论界, Cosine Similarity: 0.9289282767835759
# Words: 眺望	展望, Cosine Similarity: 0.951137248819147
# Words: 发怒	恼羞成怒, Cosine Similarity: 0.0
# Words: 执着	倔强, Cosine Similarity: 0.0
# Words: 牵强	勉强, Cosine Similarity: 0.0
# Words: 散伙	离别, Cosine Similarity: 0.0
# Words: 支柱	骨干, Cosine Similarity: 0.949191345258709
# Words: 慰劳	犒赏, Cosine Similarity: 0.0
# Words: 心态	心境, Cosine Similarity: 0.9812064276389032
# Words: 走神	愣, Cosine Similarity: 0.0
# Words: 诀窍	秘籍, Cosine Similarity: 0.0
# Words: 成果	果实, Cosine Similarity: 0.9622904251275425
# Words: 恼	怒, Cosine Similarity: 0.0
# Words: 犹豫	踟蹰不前, Cosine Similarity: 0.0
# Words: 作用	功能, Cosine Similarity: 0.9908657093196591
# Words: 怜爱	爱怜, Cosine Similarity: 0.0
# Words: 化肥	化学肥料, Cosine Similarity: 0.0
# Words: 物流	顺风, Cosine Similarity: 0.0
# Words: 皮肤	眼睛, Cosine Similarity: 0.9817204270412507
# Words: 印象	大脑, Cosine Similarity: 0.9709352346121348
# Words: 阶层	皇室, Cosine Similarity: 0.0
# Words: 新鲜	空气, Cosine Similarity: 0.9850411595919778
# Words: 法庭	律师, Cosine Similarity: 0.9692836761509116
# Words: 文章	理论, Cosine Similarity: 0.9488031711834091
# Words: 行星	月亮, Cosine Similarity: 0.8703305424439934
# Words: 日记	文章, Cosine Similarity: 0.951380239211725
# Words: 食物	水果, Cosine Similarity: 0.8646430910528232
# Words: 俗	美, Cosine Similarity: 0.9502534278653086
# Words: 会员卡	会员, Cosine Similarity: 0.0
# Words: 欧洲	南美洲, Cosine Similarity: 0.0
# Words: 风景	山水, Cosine Similarity: 0.993034353382289
# Words: 文体	骚体, Cosine Similarity: 0.0
# Words: 没劲	兴致勃勃, Cosine Similarity: 0.0
# Words: 新浪	腾讯, Cosine Similarity: 0.0
# Words: 服装	裙子, Cosine Similarity: 0.0
# Words: 凉快	炎热, Cosine Similarity: 0.0
# Words: 歌舞	迪斯科, Cosine Similarity: 0.0
# Words: 小学生	大中学生, Cosine Similarity: 0.0
# Words: 汽车	越野车, Cosine Similarity: 0.0
# Words: 团购	购买, Cosine Similarity: 0.0
# Words: 平台	环境, Cosine Similarity: 0.9293595474750227
# Words: 研讨	争论, Cosine Similarity: 0.8732062030115386
# Words: 演说	说话, Cosine Similarity: 0.91494180862756
# Words: 虚拟	编造, Cosine Similarity: 0.0
# Words: 高风险	风险, Cosine Similarity: 0.0
# Words: 感动	热泪盈眶, Cosine Similarity: 0.0
# Words: 底薪	工资, Cosine Similarity: 0.0
# Words: 扶持	提携, Cosine Similarity: 0.0
# Words: 有效	有用, Cosine Similarity: 0.9592370562452758
# Words: 圆满	大功告成, Cosine Similarity: 0.0
# Words: 邀请	诚邀, Cosine Similarity: 0.0
# Words: 破烂	破烂不堪, Cosine Similarity: 0.0
# Words: 信誉	信用, Cosine Similarity: 0.9729539238884786
# Words: 孤单	寂寞, Cosine Similarity: 0.0
# Words: 会见	会晤, Cosine Similarity: 0.7979031325902323
# Words: 背地里	背后, Cosine Similarity: 0.0
# Words: 实质	本质, Cosine Similarity: 0.9406238218274767
# Words: 枯萎	凋零, Cosine Similarity: 0.0
# Words: 互联网	因特网, Cosine Similarity: 0.9665393912372766
# Words: 课程表	课表, Cosine Similarity: 0.0
# Words: 洁癖	网瘾, Cosine Similarity: 0.0
# Words: 讲座	座位, Cosine Similarity: 0.924921392792653
# Words: 粗鲁	文盲, Cosine Similarity: 0.0
# Words: 女士	白骨精, Cosine Similarity: 0.0
# Words: 电话	设备, Cosine Similarity: 0.9364064164583569
# Words: 欢迎	迎宾, Cosine Similarity: 0.0
# Words: 气温	高温, Cosine Similarity: 0.9783072884738747
# Words: 成功	失意, Cosine Similarity: 0.0
# Words: 积极	消极, Cosine Similarity: 0.978617469878139
# Words: 君子	小人, Cosine Similarity: 0.9480630260554441
# Words: 认真	马虎, Cosine Similarity: 0.7986139399583054
# Words: 北大	清华, Cosine Similarity: 0.9659478243235127
# Words: 国王	女王, Cosine Similarity: 0.9822653577068983
# Words: 商业	工业, Cosine Similarity: 0.9898183408477716
# Words: 闺房	卧室, Cosine Similarity: 0.0
# Words: 削减	裁员, Cosine Similarity: 0.8694465018599367
# Words: 检验	查, Cosine Similarity: 0.8784274283210898
# Words: 席位	位置, Cosine Similarity: 0.9899785848483029
# Words: 奖励	记功, Cosine Similarity: 0.0
# Words: 麻利	灵活, Cosine Similarity: 0.0
# Words: 随意	随便, Cosine Similarity: 0.9161150193422494
# Words: 奋斗	努力, Cosine Similarity: 0.9829711310572193
# Words: 高兴	兴奋, Cosine Similarity: 0.9329822539229186
# Words: 猜忌	多疑, Cosine Similarity: 0.0
# Words: 轻蔑	藐视, Cosine Similarity: 0.0
# Words: 服气	口服心服, Cosine Similarity: 0.0
# Words: 入场券	门票, Cosine Similarity: 0.9429251242910598
# Words: 生物钟	地球仪, Cosine Similarity: 0.0
# Words: 年级	成绩, Cosine Similarity: 0.9776326583392727
# Words: 矩阵	数据, Cosine Similarity: 0.0
# Words: 杯子	饮料, Cosine Similarity: 0.0
# Words: 杯子	实体, Cosine Similarity: 0.0
# Words: 困倦	生病, Cosine Similarity: 0.0
# Words: 政敌	情敌, Cosine Similarity: 0.0
# Words: 灾区	地震, Cosine Similarity: 0.9178740958406386
# Words: 生日	蛋糕, Cosine Similarity: 0.9247896078444915
# Words: 泡沫	肥皂, Cosine Similarity: 0.0
# Words: 电影	导演, Cosine Similarity: 0.982163717370641
# Words: 学生	老师, Cosine Similarity: 0.9800922977207593
# Words: 自动	手动, Cosine Similarity: 0.0
# Words: 大学	中专, Cosine Similarity: 0.9804293246577276
# Words: 交易	交换, Cosine Similarity: 0.8828933479889622
# Words: 快乐	欣喜若狂, Cosine Similarity: 0.0
# Words: 邪念	非分之想, Cosine Similarity: 0.0
# Words: 平静	心平气和, Cosine Similarity: 0.0
# Words: 任命	委以重任, Cosine Similarity: 0.0
# Words: 瞎扯	编造, Cosine Similarity: 0.0
# Words: 相信	信赖, Cosine Similarity: 0.9384408565964514
# Words: 支部	面部, Cosine Similarity: 0.8818135994339596
# Words: 正义	人民, Cosine Similarity: 0.9821930606579214
# Words: 转基因	大豆, Cosine Similarity: 0.0
# Words: 白宫	宿舍, Cosine Similarity: 0.8415941959370192
# Words: 解释	分解, Cosine Similarity: 0.9390364850322042
# Words: 自卑感	历史感, Cosine Similarity: 0.0
# Words: 距离	速度, Cosine Similarity: 0.9751428324595917
# Words: 投资者	收入, Cosine Similarity: 0.982015504321337
# Words: 网络	硬件, Cosine Similarity: 0.9746963864345969
# Words: 责任	保险, Cosine Similarity: 0.989593903383317
# Words: 比赛	胜利, Cosine Similarity: 0.9460515127281085
# Words: 亲近感	荣誉感, Cosine Similarity: 0.0
# Words: 壁橱	衣服, Cosine Similarity: 0.0
# Words: 无用功	效率, Cosine Similarity: 0.0
# Words: 课程	学校, Cosine Similarity: 0.9897020062013295
# Words: 学者	学习, Cosine Similarity: 0.9845824801815384
# Words: 超市	食品, Cosine Similarity: 0.9793673688768381
# Words: 家属	丈夫, Cosine Similarity: 0.9463468988166792
# Words: 国企	私企, Cosine Similarity: 0.0
# Words: 勾画	描摹, Cosine Similarity: 0.0
# Words: 想法	主意, Cosine Similarity: 0.967907465046403
# Words: 美	靓, Cosine Similarity: 0.0
# Words: 牢固	坚不可摧, Cosine Similarity: 0.0
# Words: 凌乱	乱七八糟, Cosine Similarity: 0.0
# Words: 工作	干活儿, Cosine Similarity: 0.0
# Words: 恭贺	恭喜, Cosine Similarity: 0.0
# Words: 拍马屁	谄谀, Cosine Similarity: 0.0
# Words: PC	计算机, Cosine Similarity: 0.9229365580535446
# Words: 行	可以, Cosine Similarity: 0.9876540180196202
# Words: 死党	共和党, Cosine Similarity: 0.0
# Words: 歌剧	工业, Cosine Similarity: 0.923011058424341
# Words: 轻浮	轻松, Cosine Similarity: 0.0
# Words: 职业	教育, Cosine Similarity: 0.9906881017294962
# Words: 物理	质子, Cosine Similarity: 0.0
# Words: 网球	球拍, Cosine Similarity: 0.0
# Words: 缓慢	飞快, Cosine Similarity: 0.0
# Words: 人民币	美元, Cosine Similarity: 0.9917794943411262
# Words: 青年	中青年, Cosine Similarity: 0.9912705898505297
# Words: 境界	意境, Cosine Similarity: 0.9671061831544331
# Words: 跋扈	骄横, Cosine Similarity: 0.0
# Words: 弘扬	发扬, Cosine Similarity: 0.98486308838926
# Words: 恶劣	坏, Cosine Similarity: 0.8589700341068496
# Words: 更加	愈发, Cosine Similarity: 0.0
# Words: 优秀	出众, Cosine Similarity: 0.9591804458302073
# Words: 计算机	新闻, Cosine Similarity: 0.9900914236069134
# Words: 期刊	协会, Cosine Similarity: 0.9476133332024029
# Words: 纸老虎	狮子, Cosine Similarity: 0.0
# Words: 冷静	荒凉, Cosine Similarity: 0.9422048649392516
# Words: 乡村	故事, Cosine Similarity: 0.96198620950764
# Words: 出路	山路, Cosine Similarity: 0.9451321906677468
# Words: 能源	危机, Cosine Similarity: 0.9713281433159782
# Words: 房价	面积, Cosine Similarity: 0.9866363405337324
# Words: 龙头	老大, Cosine Similarity: 0.8973851408748761
# Words: 安排	部署, Cosine Similarity: 0.9796781131747466
# Words: 文明	吸烟者, Cosine Similarity: 0.0
# Words: 普及	担当, Cosine Similarity: 0.9562048657224671
# Words: 困难	自怨自艾, Cosine Similarity: 0.0
# Words: 造型	照片, Cosine Similarity: 0.9731407180526549
# Words: 抠门儿	小气, Cosine Similarity: 0.0
# Words: 假货	赝品, Cosine Similarity: 0.0
# Words: 拖后腿	拉后腿, Cosine Similarity: 0.0
# Words: 天下	气候, Cosine Similarity: 0.9509814320188149
# Words: 轻	善, Cosine Similarity: 0.9727563879398767
# Words: 日程	季度, Cosine Similarity: 0.9362238053308684
# Words: 宇宙	蚂蚁, Cosine Similarity: 0.0
# Words: 面包店	绿豆粥, Cosine Similarity: 0.0
# Words: 结盟	无理取闹, Cosine Similarity: 0.0
# Words: 免税店	飞机, Cosine Similarity: 0.0
# Words: 逃课	创业, Cosine Similarity: 0.0
# Words: 态度	秋波, Cosine Similarity: 0.0
# Words: 但	但是, Cosine Similarity: 0.9963815776639247
# Words: 赢	胜, Cosine Similarity: 0.9173157974639609
# Words: 调查	努力, Cosine Similarity: 0.9863743531657376
# Words: 玻璃	魔术师, Cosine Similarity: 0.0
# Words: 干扰	上网, Cosine Similarity: 0.9648330078214824
# Words: 课堂	美食, Cosine Similarity: 0.9579819175653307
# Words: 情节	黄色, Cosine Similarity: 0.9511679708963472
# Words: 计算机	电脑, Cosine Similarity: 0.9902774580467368
# Words: 讲价	打架, Cosine Similarity: 0.0
# Words: 教授	黄瓜, Cosine Similarity: 0.7986282098500845
# Words: 控制	恐高, Cosine Similarity: 0.0
# Words: 阻力	天花板, Cosine Similarity: 0.8097235149768602
# Words: WTO	世界贸易组织, Cosine Similarity: 0.0
# Words: 紫禁城	故宫, Cosine Similarity: 0.9479572308723396
# Words: 算盘	计算机, Cosine Similarity: 0.0

# %%
# 定义一个函数，用于获取稀疏矩阵的奇异值分解结果
def get_sigma(csr_matrix, choose=10):
    # 对稀疏矩阵进行奇异值分解，并获取奇异值数组
    sigma = np.linalg.svd(csr_matrix.toarray(), compute_uv=False)

    # 获取词汇表大小
    vocab_size = len(sigma)

    # 指定要保存的文件路径
    file_path = f"sigma/array_data_vocab_size_{vocab_size}.txt"

    # 使用 numpy.savetxt 函数将数组写入文本文件
    np.savetxt(file_path, sigma)

    # 统计奇异值数组中为0的元素个数
    zero_count = 0
    for i in sigma:
        if i == 0.0:
            zero_count += 1

    # 计算所有奇异值之和、前choose个奇异值之和，并返回这些值
    sum_sigma = sum(sigma)
    sum_choose = sum(sigma[:choose])
    return sigma, zero_count, sum_sigma, sum_choose

# %%
sigma, zero_count, sum_sigma, sum_choose = get_sigma(csr_matrix)

# %%
zero_count, sum_sigma, sum_choose

# %%
import numpy as np

def load_sigma(file_path, choose=100):
    # 使用NumPy的loadtxt函数加载奇异值数组
    sigma = np.loadtxt(file_path)

    zero_count = 0
    for i in sigma:
        if i == 0.0:
            zero_count += 1

    one_count = 0
    for i in sigma:
        if i < 0.01:
            one_count += 1

    sum_sigma = sum(sigma)
    sum_choose = sum(sigma[:choose])
    return sigma, one_count, zero_count, sum_sigma, sum_choose, sum_choose / sum_sigma


# 指定奇异值数组保存的文件路径
file_path = "sigma/array_data_vocab_size_20000.txt"

# 调用load_sigma函数加载奇异值数组
sigma, one_count, zero_count, sum_sigma, sum_choose, bili = load_sigma(file_path)

# %%
one_count, zero_count, sum_sigma, sum_choose, bili
# Out:
# (24, 0, 561109.1086706324, 211065.9964873199, 0.3761585638618003)
